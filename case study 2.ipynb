# %%
import numpy as np 
import pandas as pd 
import seaborn as ns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("women_entreprenuer.csv", sep = ";")

# %%
data
# Out:
#     No                 Country Level of development European Union Membership  \
# 0    4                 Austria            Developed                    Member
# 1    6                 Belgium            Developed                    Member
# 2   17                 Estonia            Developed                    Member
# 3   18                 Finland            Developed                    Member
# 4   19                  France            Developed                    Member
# 5   20                 Germany            Developed                    Member
# 6   22                  Greece            Developed                    Member
# 7   28                 Ireland            Developed                    Member
# 8   30                   Italy            Developed                    Member
# 9   34                  Latvia            Developed                    Member
# 10  35               Lithuania            Developed                    Member
# ...

# %%
data.head()
# Out:
#    No  Country Level of development European Union Membership Currency  \
# 0   4  Austria            Developed                    Member     Euro
# 1   6  Belgium            Developed                    Member     Euro
# 2  17  Estonia            Developed                    Member     Euro
# 3  18  Finland            Developed                    Member     Euro
# 4  19   France            Developed                    Member     Euro
#
#    Women Entrepreneurship Index  Entrepreneurship Index  Inflation rate  \
# 0                          54.9                    64.9            0.90
# 1                          63.6                    65.5            0.60
# 2                          55.4                    60.2           -0.88
# 3                          66.4                    65.7           -0.20
# 4                          68.8                    67.3            0.00
#
#    Female Labor Force Participation Rate
# 0                                   67.1
# ...

# %%
data.tail()
# Out:
#     No       Country Level of development European Union Membership  \
# 46  48  Saudi Arabia           Developing                Not Member
# 47  57      Thailand           Developing                Not Member
# 48  58       Tunisia           Developing                Not Member
# 49  59        Turkey           Developing                Not Member
# 50  60       Uruguay           Developing                Not Member
#
#              Currency  Women Entrepreneurship Index  Entrepreneurship Index  \
# 46  National Currency                          37.0                    49.6
# 47  National Currency                          36.6                    32.1
# 48  National Currency                          30.7                    35.5
# 49  National Currency                          39.3                    54.6
# 50  National Currency                          44.5                    41.4
#
#     Inflation rate  Female Labor Force Participation Rate
# ...

# %%
data.shape
# Out:
# (51, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   No                                     51 non-null     int64
#  1   Country                                51 non-null     object
#  2   Level of development                   51 non-null     object
#  3   European Union Membership              51 non-null     object
#  4   Currency                               51 non-null     object
#  5   Women Entrepreneurship Index           51 non-null     float64
#  6   Entrepreneurship Index                 51 non-null     float64
#  7   Inflation rate                         51 non-null     float64
#  8   Female Labor Force Participation Rate  51 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.7+ KB

# %%
data.describe()
# Out:
#               No  Women Entrepreneurship Index  Entrepreneurship Index  \
# count  51.000000                     51.000000               51.000000
# mean   29.980392                     47.835294               47.241176
# std    18.017203                     14.268480               16.193149
# min     1.000000                     25.300000               24.800000
# 25%    14.500000                     36.350000               31.900000
# 50%    30.000000                     44.500000               42.700000
# 75%    45.500000                     59.150000               65.400000
# max    60.000000                     74.800000               77.600000
#
#        Inflation rate  Female Labor Force Participation Rate
# count       51.000000                              51.000000
# mean         2.587647                              58.481765
# std          5.380639                              13.864567
# min         -2.250000                              13.000000
# ...

# %%
data.describe().columns
# Out:
# Index(['No', 'Women Entrepreneurship Index', 'Entrepreneurship Index',
#        'Inflation rate', 'Female Labor Force Participation Rate'],
#       dtype='object')

# %%
data.isnull( ).sum( )
# Out:
# No                                       0
# Country                                  0
# Level of development                     0
# European Union Membership                0
# Currency                                 0
# Women Entrepreneurship Index             0
# Entrepreneurship Index                   0
# Inflation rate                           0
# Female Labor Force Participation Rate    0
# dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data_cat = data[['Country', 'Level of development', 'European Union Membership', 'Currency']]
data_num = data[['Women Entrepreneurship Index', 'Entrepreneurship Index', 'Inflation rate', 'Female Labor Force Participation Rate']]

# %%
data_cat['Level of development'].value_counts().sort_index(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data_cat['European Union Membership'].value_counts().sort_index(ascending=False).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='European Union Membership'>

# %%
data_cat['Currency'].value_counts().sort_index(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
table=data_cat.groupby(['Currency','Level of development']).count()
table
# Out:
#                                         Country  European Union Membership
# Currency          Level of development
# Euro              Developed                  15                         15
# National Currency Developed                  12                         12
#                   Developing                 24                         24

# %%
plt.hist(data_num['Women Entrepreneurship Index'],bins=10)
plt.title("Women Entrepreneurship Index")
plt.show()

# %%
plt.figure(figsize=(12,7))
ns.barplot(x=data_cat.Country,y=data_num['Women Entrepreneurship Index'])
plt.xticks(rotation=90)
plt.show()

# %%
top_WEI=data.groupby('Country').sum()
top_WEI.drop('No',axis=1,inplace=True)
top_WEI.sort_values(by='Women Entrepreneurship Index',ascending=False).head()
# Out:
#              Women Entrepreneurship Index  Entrepreneurship Index  \
# Country
# Australia                            74.8                    77.6
# Denmark                              69.7                    71.4
# Netherlands                          69.3                    66.5
# France                               68.8                    67.3
# Iceland                              68.0                    70.4
#
#              Inflation rate  Female Labor Force Participation Rate
# Country
# Australia               1.5                                   66.8
# Denmark                 0.5                                   70.3
# Netherlands             0.6                                   69.2
# France                  0.0                                   60.6
# Iceland                 1.6                                   82.3

# %%
top_LOD=data.groupby('Level of development').sum()
top_LOD.drop('No',axis=1,inplace=True)
top_LOD.sort_values(by='Women Entrepreneurship Index',ascending=False)
# Out:
#                       Women Entrepreneurship Index  Entrepreneurship Index  \
# Level of development
# Developed                                   1602.7                  1606.1
# Developing                                   836.9                   803.2
#
#                       Inflation rate  Female Labor Force Participation Rate
# Level of development
# Developed                       0.38                                1703.58
# Developing                    131.59                                1278.99

# %%
top_WEI=data.groupby('Country').sum()
top_WEI.drop('No',axis=1,inplace=True)
top_WEI.sort_values(by='Women Entrepreneurship Index',ascending=False).tail()
# Out:
#          Women Entrepreneurship Index  Entrepreneurship Index  Inflation rate  \
# Country
# Bolivia                          29.7                    28.0             4.1
# Egypt                            27.7                    28.1            11.0
# Algeria                          27.4                    30.2             4.8
# Ghana                            25.8                    24.8            17.2
# India                            25.3                    25.3             5.9
#
#          Female Labor Force Participation Rate
# Country
# Bolivia                                   69.4
# Egypt                                     64.6
# Algeria                                   18.0
# Ghana                                     60.8
# India                                     61.1

# %%
ns.boxplot(x='Women Entrepreneurship Index',y='Level of development',data=data);

# %%
top_IR=data.groupby('Country').sum()
top_IR.drop(['No','Women Entrepreneurship Index','Entrepreneurship Index','Female Labor Force Participation Rate'],axis=1,inplace=True)
top_IR.sort_values(by='Inflation rate',ascending=False).head()
# Out:
#            Inflation rate
# Country
# Argentina           26.50
# Ghana               17.20
# Russia              15.50
# Egypt               11.00
# Brazil              10.67

# %%
top_IR=data.groupby('Country').sum()
top_IR.drop(['No','Women Entrepreneurship Index','Entrepreneurship Index','Female Labor Force Participation Rate'],axis=1,inplace=True)
top_IR.sort_values(by='Inflation rate',ascending=False).tail()
# Out:
#                         Inflation rate
# Country
# Lithuania                        -0.90
# Bosnia and Herzegovina           -1.00
# Switzerland                      -1.10
# Greece                           -1.70
# El Salvador                      -2.25

# %%
ns.boxplot(x='Inflation rate',y='Level of development',data=data);

# %%
top_FLPR=data.groupby('Country').sum()
top_FLPR.drop(['No','Women Entrepreneurship Index','Entrepreneurship Index','Inflation rate'],axis=1,inplace=True)
top_FLPR.sort_values(by='Female Labor Force Participation Rate',ascending=False).head()
# Out:
#              Female Labor Force Participation Rate
# Country
# Iceland                                       82.3
# Switzerland                                   74.7
# Sweden                                        74.0
# Macedonia                                     73.0
# Denmark                                       70.3

# %%
top_FLPR=data.groupby('Country').sum()
top_FLPR.drop(['No','Women Entrepreneurship Index','Entrepreneurship Index','Inflation rate'],axis=1,inplace=True)
top_FLPR.sort_values(by='Female Labor Force Participation Rate',ascending=False).tail()
# Out:
#               Female Labor Force Participation Rate
# Country
# Jamaica                                       37.70
# Turkey                                        30.40
# Tunisia                                       25.19
# Algeria                                       18.00
# Saudi Arabia                                  13.00

# %%
x=data[['Inflation rate']].values
y=data['Women Entrepreneurship Index'].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()
reg=model.fit(X_train,y_train)

# %%
#pip install statsmodels

# %%
import statsmodels.api as sm
model = sm.OLS(y,sm.add_constant(x)).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     12.83
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):           0.000782
# Time:                        05:34:42   Log-Likelihood:                -201.49
# No. Observations:                  51   AIC:                             407.0
# Df Residuals:                      49   BIC:                             410.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         50.9611      1.997     25.513      0.000      46.947      54.975
# ...

# %%
x1=data[['Female Labor Force Participation Rate']].values
y1=data['Women Entrepreneurship Index'].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2)

# %%
model1=LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model1=sm.OLS(y1,sm.add_constant(x1)).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     11.86
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):            0.00119
# Time:                        05:34:42   Log-Likelihood:                -201.90
# No. Observations:                  51   AIC:                             407.8
# Df Residuals:                      49   BIC:                             411.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.2711      7.925      2.684      0.010       5.346      37.197
# ...

# %%
x2=data[['Entrepreneurship Index']].values
y2=data['Women Entrepreneurship Index'].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x2,y2,test_size=0.2)

# %%
model2=LinearRegression()
model2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model2=sm.OLS(y1,sm.add_constant(x1)).fit()

# %%
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     11.86
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):            0.00119
# Time:                        05:34:43   Log-Likelihood:                -201.90
# No. Observations:                  51   AIC:                             407.8
# Df Residuals:                      49   BIC:                             411.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.2711      7.925      2.684      0.010       5.346      37.197
# ...

# %%
x3=data[['Inflation rate','Female Labor Force Participation Rate']].values
y3=data['Women Entrepreneurship Index'].values
model3=sm.OLS(y3,sm.add_constant(x3)).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     12.83
# Date:                Thu, 17 Mar 2022   Prob (F-statistic):           0.000782
# Time:                        05:34:43   Log-Likelihood:                -201.49
# No. Observations:                  51   AIC:                             407.0
# Df Residuals:                      49   BIC:                             410.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         50.9611      1.997     25.513      0.000      46.947      54.975
# ...

# %%
model3=LinearRegression()
model3.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Training Accuracy :",model3.score(X_train,y_train))
print("Testing Accuracy :",model3.score(X_test,y_test))
# Out:
# Training Accuracy : 0.811422639840825
# Testing Accuracy : 0.8337328485746857
